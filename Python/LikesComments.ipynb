# %%
import pandas as pd
import random
from math import sqrt, log, pi, cos, sin
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(color_codes=True)

# %%
df = pd.read_csv("likes_comments.csv")

# %%
sns.jointplot(x="likedcount", y="replycount", data=df, kind="kde", fill=True)
plt.show()
